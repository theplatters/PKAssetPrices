# %%
using PKAssetPrices.Dynamic: DynamicModel, DiscreteTime, DynamicParametrization, solve_model, @model
using PKAssetPrices
using CairoMakie
# Out:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# [ Info: AD = 4.21
# [ Info: AQ = 6.0
# [ Info: P = 1.76
# [ Info: AP = 2.0
# [ Info: r = 0.11
# [ Info: AD = 4.21
# [ Info: AQ = 6.0
# [ Info: P = 1.76
# [ Info: AP = 2.0
# [ Info: r = 0.11
# [ Info: AQ = 6.0
# [ Info: P = 1.76
# [ Info: AP = 2.0
# [ Info: r = 0.11
# [ Info: AQ = 6.0
# [ Info: P = 1.76
# [ Info: AP = 2.0
# [ Info: r = 0.11
# [ Info: AQ = 6.0
# [ Info: P = 1.76
# [ Info: AP = 2.0
# [ Info: r = 0.11
# [ Info: P = 1.76
# [ Info: AP = 2.0
# [ Info: r = 0.11
# [ Info: AQ = 6.0
# [ Info: P = 1.76
# [ Info: AP = 2.0
# [ Info: r = 0.11
# [ Info: AQ = 6.0
# [ Info: P = 1.0
# [ Info: AP = [1.0, 1.0]
# [ Info: r = 0.11
# [ Info: AQ = 6.0
# [ Info: P = 1.76
# [ Info: AP = [1.0, 1.0]
# [ Info: r = 0.11

# %%
sol_Q1 =  solve_model(Dynamic.DynQ1)
sol_Q2 =  solve_model(Dynamic.DynQ2)
sol_Q3 =  solve_model(Dynamic.DynQ3)
sol_Q4 =  solve_model(Dynamic.DynQ4)
# Out:
# UndefVarError: `DynQ4` not defined in `PKAssetPrices.Dynamic`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] getproperty(x::Module, f::Symbol)
#
#    @ Base ./Base_compiler.jl:47
#
#  [2] top-level scope
#
#    @ ~/Schreibtisch/Arbeit/PKAssetPrices/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:5
